# %% [markdown]
# Ava Gombkoto - Speed Bumps
#
# **Which neighborhood has the most speed bumps?**

# %%
import pandas as pd
import numpy
humps = pd.read_csv("speed-humps.csv", dtype={2:str})

# %%
#get the different neighborhoods
neighborhoods = humps.groupby("neighborhood").count()
neighborhoods
# Out:
#                      _id  id  hump_id  locator_address_number  locator_street  \
# neighborhood
# Bloomfield             3   3        3                       3               3
# Brookline              4   4        4                       4               4
# Carrick                9   9        9                       9               9
# Central Oakland        1   1        1                       0               1
# Garfield               3   3        3                       3               3
# Highland Park          2   2        2                       2               2
# Homewood South         4   4        4                       4               4
# Mount Washington       3   3        3                       3               3
# North Oakland          6   6        6                       5               6
# Overbrook              1   1        1                       1               1
# Perry North            4   4        4                       4               4
# ...

# %%
#make a list of neighborhoods
the_hoods = humps.loc[:,"neighborhood"].tolist()
the_hoods = numpy.array(the_hoods)
the_hoods = numpy.unique(the_hoods)
#make a list of the number of ids
bumps = neighborhoods.loc[:,"id"].tolist()
#put the lists together in a series
speed_humps = pd.Series(bumps, index=the_hoods)
speed_humps
# Out:
# Bloomfield              3
# Brookline               4
# Carrick                 9
# Central Oakland         1
# Garfield                3
# Highland Park           2
# Homewood South          4
# Mount Washington        3
# North Oakland           6
# Overbrook               1
# Perry North             4
# Polish Hill             6
# South Side Flats        3
# South Side Slopes       4
# Squirrel Hill North     3
# Squirrel Hill South    18
# Stanton Heights         1
# Upper Hill              4
# dtype: int64

# %%
#compare the neighborhoods and decide which is has the most speed bumps
most_bumps=max(bumps)
print(most_bumps)
index = bumps.index(most_bumps)
neighborhood = the_hoods[index]
print(neighborhood)
# Out:
# 18
# Squirrel Hill South

# %% [markdown]
# **Conclusion**
#
# Squirrel Hill South is the best neighborhood based on the number of speed bumps. It has the most speed bumps with a total of 18
